# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import raw data and have a look

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

raw_df = pd.read_csv("../data/raw/hotel_vienna_restricted.csv")
raw_df.head(10)
# Out:
#    country city_actual  rating_count center1distance center1label  \
# 0  Austria      Vienna         189.0       1.7 miles  City centre
# 1  Austria      Vienna          53.0       1.4 miles  City centre
# 2  Austria      Vienna          55.0       1.7 miles  City centre
# 3  Austria      Vienna          33.0       1.2 miles  City centre
# 4  Austria      Vienna          57.0       0.9 miles  City centre
# 5  Austria      Vienna         161.0        1.0 mile  City centre
# 6  Austria      Vienna         203.0       1.1 miles  City centre
# 7  Austria      Vienna         251.0       0.8 miles  City centre
# 8  Austria      Vienna          18.0       1.7 miles  City centre
# 9  Austria      Vienna          20.0       0.9 miles  City centre
#
#   center2distance center2label neighbourhood  price        price_night  ...  \
# 0       3.8 miles    Donauturm   17. Hernals     81  price for 1 night  ...
# 1       2.5 miles    Donauturm    Alsergrund     85  price for 1 night  ...
# 2       2.5 miles    Donauturm    Alsergrund     83  price for 1 night  ...
# 3       2.8 miles    Donauturm    Alsergrund     82  price for 1 night  ...
# 4       2.4 miles    Donauturm    Alsergrund    103  price for 1 night  ...
# 5       2.7 miles    Donauturm    Alsergrund    150  price for 1 night  ...
# 6       2.7 miles    Donauturm    Alsergrund     60  price for 1 night  ...
# 7       2.9 miles    Donauturm    Alsergrund    128  price for 1 night  ...
# 8       2.6 miles    Donauturm    Alsergrund     85  price for 1 night  ...
# 9       2.8 miles    Donauturm    Alsergrund     77  price for 1 night  ...
#
#       offer_cat  year  month  weekend holiday nnights  acc_type  ratings  \
# 0   1-15% offer  2017     11        0       0       1     Hotel      3.9
# 1  15-50% offer  2017     11        0       0       1     Hotel      3.7
# 2  15-50% offer  2017     11        0       0       1     Hotel      4.0
# 3  15-50% offer  2017     11        0       0       1     Hotel      3.9
# 4   0% no offer  2017     11        0       0       1     Hotel      3.9
# 5   0% no offer  2017     11        0       0       1     Hotel      4.6
# 6   1-15% offer  2017     11        0       0       1     Hotel      4.1
# 7   0% no offer  2017     11        0       0       1     Hotel      4.0
# 8   1-15% offer  2017     11        0       0       1     Hotel      4.1
# 9  15-50% offer  2017     11        0       0       1     Hotel      3.7
#
#    distance distance_alter
# 0       1.7            3.8
# 1       1.4            2.5
# 2       1.7            2.5
# 3       1.2            2.8
# 4       0.9            2.4
# 5       1.0            2.7
# 6       1.1            2.7
# 7       0.8            2.9
# 8       1.7            2.6
# 9       0.9            2.8
#
# [10 rows x 29 columns]

# %%
raw_df.shape
# Out:
# (217, 29)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             217 non-null    object
#  1   city_actual         217 non-null    object
#  2   rating_count        217 non-null    float64
#  3   center1distance     217 non-null    object
#  4   center1label        217 non-null    object
#  5   center2distance     217 non-null    object
#  6   center2label        217 non-null    object
#  7   neighbourhood       217 non-null    object
#  8   price               217 non-null    int64
#  9   price_night         217 non-null    object
#  10  city                217 non-null    object
#  11  stars               217 non-null    float64
#  12  ratingta            214 non-null    float64
#  13  ratingta_count      214 non-null    float64
#  14  accommodationtype   217 non-null    object
#  15  guestreviewsrating  217 non-null    object
#  16  scarce_room         217 non-null    int64
#  17  hotel_id            217 non-null    float64
#  18  offer               217 non-null    int64
#  19  offer_cat           217 non-null    object
#  20  year                217 non-null    int64
#  21  month               217 non-null    int64
#  22  weekend             217 non-null    int64
#  23  holiday             217 non-null    int64
#  24  nnights             217 non-null    int64
#  25  acc_type            217 non-null    object
#  26  ratings             217 non-null    float64
#  27  distance            217 non-null    float64
#  28  distance_alter      217 non-null    float64
# dtypes: float64(8), int64(8), object(13)
# memory usage: 49.3+ KB

# %% [markdown]
# ## Check on the missing values

# %%
raw_df.loc[raw_df["ratingta"].isnull()]
# Out:
#      country city_actual  rating_count center1distance center1label  \
# 136  Austria      Vienna           6.0       0.8 miles  City centre
# 167  Austria      Vienna          18.0       2.6 miles  City centre
# 204  Austria      Vienna          15.0       0.9 miles  City centre
#
#     center2distance center2label neighbourhood  price        price_night  ...  \
# 136       3.6 miles    Donauturm        Neubau    113  price for 1 night  ...
# 167       5.4 miles    Donauturm    Schonbrunn     83  price for 1 night  ...
# 204       3.6 miles    Donauturm        Wieden    126  price for 1 night  ...
#
#         offer_cat  year  month  weekend holiday nnights  acc_type  ratings  \
# 136   0% no offer  2017     11        0       0       1     Hotel      3.7
# 167  15-50% offer  2017     11        0       0       1     Hotel      4.5
# 204   1-15% offer  2017     11        0       0       1     Hotel      4.5
#
#      distance distance_alter
# 136       0.8            3.6
# 167       2.6            5.4
# 204       0.9            3.6
#
# [3 rows x 29 columns]

# %% [markdown]
# ## Get rid of the missing values

# %%
df=raw_df.dropna(subset=["ratingta"])
df
# Out:
#      country city_actual  rating_count center1distance center1label  \
# 0    Austria      Vienna         189.0       1.7 miles  City centre
# 1    Austria      Vienna          53.0       1.4 miles  City centre
# 2    Austria      Vienna          55.0       1.7 miles  City centre
# 3    Austria      Vienna          33.0       1.2 miles  City centre
# 4    Austria      Vienna          57.0       0.9 miles  City centre
# ..       ...         ...           ...             ...          ...
# 212  Austria      Vienna          77.0       1.2 miles  City centre
# 213  Austria      Vienna         572.0       1.5 miles  City centre
# 214  Austria      Vienna          53.0       1.5 miles  City centre
# 215  Austria      Vienna         112.0        1.0 mile  City centre
# 216  Austria      Vienna         169.0       1.4 miles  City centre
#
#     center2distance center2label neighbourhood  price        price_night  ...  \
# 0         3.8 miles    Donauturm   17. Hernals     81  price for 1 night  ...
# 1         2.5 miles    Donauturm    Alsergrund     85  price for 1 night  ...
# 2         2.5 miles    Donauturm    Alsergrund     83  price for 1 night  ...
# 3         2.8 miles    Donauturm    Alsergrund     82  price for 1 night  ...
# 4         2.4 miles    Donauturm    Alsergrund    103  price for 1 night  ...
# ..              ...          ...           ...    ...                ...  ...
# 212       3.7 miles    Donauturm        Wieden    100  price for 1 night  ...
# 213       3.9 miles    Donauturm        Wieden     95  price for 1 night  ...
# 214       4.0 miles    Donauturm        Wieden     73  price for 1 night  ...
# 215       3.7 miles    Donauturm        Wieden    100  price for 1 night  ...
# 216       4.1 miles    Donauturm        Wieden     58  price for 1 night  ...
#
#         offer_cat  year  month  weekend holiday nnights  acc_type  ratings  \
# 0     1-15% offer  2017     11        0       0       1     Hotel      3.9
# 1    15-50% offer  2017     11        0       0       1     Hotel      3.7
# 2    15-50% offer  2017     11        0       0       1     Hotel      4.0
# 3    15-50% offer  2017     11        0       0       1     Hotel      3.9
# 4     0% no offer  2017     11        0       0       1     Hotel      3.9
# ..            ...   ...    ...      ...     ...     ...       ...      ...
# 212   1-15% offer  2017     11        0       0       1     Hotel      4.0
# 213   1-15% offer  2017     11        0       0       1     Hotel      4.1
# 214   1-15% offer  2017     11        0       0       1     Hotel      3.4
# 215   0% no offer  2017     11        0       0       1     Hotel      4.4
# 216  15-50% offer  2017     11        0       0       1     Hotel      3.2
#
#      distance distance_alter
# 0         1.7            3.8
# 1         1.4            2.5
# 2         1.7            2.5
# 3         1.2            2.8
# 4         0.9            2.4
# ..        ...            ...
# 212       1.2            3.7
# 213       1.5            3.9
# 214       1.5            4.0
# 215       1.0            3.7
# 216       1.4            4.1
#
# [214 rows x 29 columns]

# %% [markdown]
# ## Get rid of the hotels that are not in Vienna

# %%
df = df.loc[df["city_actual"] == "Vienna"]
df
# Out:
#      country city_actual  rating_count center1distance center1label  \
# 0    Austria      Vienna         189.0       1.7 miles  City centre
# 1    Austria      Vienna          53.0       1.4 miles  City centre
# 2    Austria      Vienna          55.0       1.7 miles  City centre
# 3    Austria      Vienna          33.0       1.2 miles  City centre
# 4    Austria      Vienna          57.0       0.9 miles  City centre
# ..       ...         ...           ...             ...          ...
# 212  Austria      Vienna          77.0       1.2 miles  City centre
# 213  Austria      Vienna         572.0       1.5 miles  City centre
# 214  Austria      Vienna          53.0       1.5 miles  City centre
# 215  Austria      Vienna         112.0        1.0 mile  City centre
# 216  Austria      Vienna         169.0       1.4 miles  City centre
#
#     center2distance center2label neighbourhood  price        price_night  ...  \
# 0         3.8 miles    Donauturm   17. Hernals     81  price for 1 night  ...
# 1         2.5 miles    Donauturm    Alsergrund     85  price for 1 night  ...
# 2         2.5 miles    Donauturm    Alsergrund     83  price for 1 night  ...
# 3         2.8 miles    Donauturm    Alsergrund     82  price for 1 night  ...
# 4         2.4 miles    Donauturm    Alsergrund    103  price for 1 night  ...
# ..              ...          ...           ...    ...                ...  ...
# 212       3.7 miles    Donauturm        Wieden    100  price for 1 night  ...
# 213       3.9 miles    Donauturm        Wieden     95  price for 1 night  ...
# 214       4.0 miles    Donauturm        Wieden     73  price for 1 night  ...
# 215       3.7 miles    Donauturm        Wieden    100  price for 1 night  ...
# 216       4.1 miles    Donauturm        Wieden     58  price for 1 night  ...
#
#         offer_cat  year  month  weekend holiday nnights  acc_type  ratings  \
# 0     1-15% offer  2017     11        0       0       1     Hotel      3.9
# 1    15-50% offer  2017     11        0       0       1     Hotel      3.7
# 2    15-50% offer  2017     11        0       0       1     Hotel      4.0
# 3    15-50% offer  2017     11        0       0       1     Hotel      3.9
# 4     0% no offer  2017     11        0       0       1     Hotel      3.9
# ..            ...   ...    ...      ...     ...     ...       ...      ...
# 212   1-15% offer  2017     11        0       0       1     Hotel      4.0
# 213   1-15% offer  2017     11        0       0       1     Hotel      4.1
# 214   1-15% offer  2017     11        0       0       1     Hotel      3.4
# 215   0% no offer  2017     11        0       0       1     Hotel      4.4
# 216  15-50% offer  2017     11        0       0       1     Hotel      3.2
#
#      distance distance_alter
# 0         1.7            3.8
# 1         1.4            2.5
# 2         1.7            2.5
# 3         1.2            2.8
# 4         0.9            2.4
# ..        ...            ...
# 212       1.2            3.7
# 213       1.5            3.9
# 214       1.5            4.0
# 215       1.0            3.7
# 216       1.4            4.1
#
# [204 rows x 29 columns]

# %% [markdown]
# ## Write out the munged data

# %%
df.to_csv("../data/processed/hotel_vienna_munged.csv", index=False)
